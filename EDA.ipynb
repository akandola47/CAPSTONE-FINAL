# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df= pd.read_csv('WorldCupcleaned.csv')
print(df.head())

print
# Out:
#      Stage         Stadium         City Home Team Name  Home Team Goals  \
# 0  Group 1         Pocitos  Montevideo          France                4
# 1  Group 4  Parque Central  Montevideo             USA                3
# 2  Group 2  Parque Central  Montevideo      Yugoslavia                2
# 3  Group 3         Pocitos  Montevideo         Romania                3
# 4  Group 1  Parque Central  Montevideo       Argentina                1
#
#    Away Team Goals Away Team Name  Attendance
# 0                1         Mexico      4444.0
# 1                0        Belgium     18346.0
# 2                1         Brazil     24059.0
# 3                1           Peru      2549.0
# 4                0         France     23409.0
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
df.info()

df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 852 entries, 0 to 851
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Stage            852 non-null    object
#  1   Stadium          852 non-null    object
#  2   City             852 non-null    object
#  3   Home Team Name   852 non-null    object
#  4   Home Team Goals  852 non-null    int64
#  5   Away Team Goals  852 non-null    int64
#  6   Away Team Name   852 non-null    object
#  7   Attendance       850 non-null    float64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 53.4+ KB
#        Home Team Goals  Away Team Goals     Attendance
# count       852.000000       852.000000     850.000000
# mean          1.811033         1.022300   45164.800000
# std           1.610255         1.087573   23485.249247
# min           0.000000         0.000000    2000.000000
# 25%           1.000000         0.000000   30000.000000
# 50%           2.000000         1.000000   41579.500000
# 75%           3.000000         2.000000   61374.500000
# max          10.000000         7.000000  173850.000000

# %%
df.sample(20)
# Out:
#                         Stage  \
# 850  Play-off for third place
# 670                   Group F
# 472                   Group F
# 260                   Group A
# 268     Match for third place
# 187                   Group 4
# 346                   Group 3
# 573            Quarter-finals
# 307                     Final
# 550                   Group A
# 468                   Group A
# 292                   Group 4
# 539                   Group D
# 744                   Group C
# 202                   Group 4
# 148                   Group 1
# 372                   Group A
# 606                   Group C
# 377                   Group F
# 497                   Group F
#
#                                                Stadium  \
# 850                                   Estadio Nacional
# 670                                    Franken-Stadion
# 472                                        RFK Stadium
# 260                               Niedersachsenstadion
# 268                                     Olympiastadion
# 187                                      Ayresome Park
# 346                                             Sarria
# 573                                       La Beaujoire
# 307  El Monumental - Estadio Monumental Antonio Ves...
# 550                            Stade Geoffroy Guichard
# 468                                          Rose Bowl
# 292                  Estadio Ol�mpico Chateau Carreras
# 539                            Stade Geoffroy Guichard
# 744                             Port Elizabeth Stadium
# 202                            Nou Camp - Estadio Le�n
# 148                                    Carlos Dittborn
# 372                                         Cuauhtemoc
# 606                           Incheon Football Stadium
# 377                                        Tecnologico
# 497                                        RFK Stadium
#
#                                    City Home Team Name  Home Team Goals  \
# 850                           Brasilia          Brazil                0
# 670                          Nuremberg           Japan                0
# 472                      Washington Dc     Netherlands                2
# 260                            Hanover       Argentina                1
# 268                             Munich          Brazil                0
# 187                      Middlesbrough       Korea DPR                1
# 346                          Barcelona           Italy                2
# 573                             Nantes          Brazil                3
# 307                       Buenos Aires       Argentina                3
# 550                      Saint-Etienne        Scotland                0
# 468                        Los Angeles        Colombia                1
# 292                            Cordoba            Peru                4
# 539                      Saint-Etienne           Spain                0
# 744  Nelson Mandela Bay/Port Elizabeth        Slovenia                0
# 202                               Leon            Peru                3
# 148                              Arica    Soviet Union                4
# 372                             Puebla           Italy                1
# 606                            Incheon      Costa Rica                1
# 377                          Monterrey         England                0
# 497                      Washington Dc         Belgium                0
#
#      Away Team Goals Away Team Name  Attendance
# 850                3    Netherlands     68034.0
# 670                0        Croatia     41000.0
# 472                1   Saudi Arabia     50535.0
# 260                2         Brazil     39400.0
# 268                1         Poland     77100.0
# 187                0          Italy     17829.0
# 346                1      Argentina     43000.0
# 573                2        Denmark     35500.0
# 307                1    Netherlands     71483.0
# 550                3        Morocco     30600.0
# 468                3        Romania     91856.0
# 292                1           Iran     21262.0
# 539                0       Paraguay     30600.0
# 744                1        England     36893.0
# 202                2       Bulgaria     13765.0
# 148                4       Colombia      8040.0
# 372                1      Argentina     32000.0
# 606                1         Turkey     42299.0
# 377                0        Morocco     20200.0
# 497                1   Saudi Arabia     52959.0

# %%
num_df=df.select_dtypes(include = ['int64','float'])

plt.figure
correlation=num_df.corr()
sns.heatmap(correlation, annot=True,cmap='coolwarm')
plt.title('Correlation Heatmap of attributes')
plt.show()

# %%
#The EDA process or exploratory data analaysis process is where you take preprocessed data and then process it by taking out missing values, outliers and other values that do not belong. First we collect the data, find out what variables we need, clean the data and then visualize the results. I used mean median mode, standard deviation, and then used charts to display different types of information. The report shows us how the data is spreadout and it allows us to see the mean, median and mode of all the attributes. The heatmap also shows the correlation between home team goals, away team goals and the amount of attendance. I will be able to add more graphs and visuals within the week.

# %%
df.hist(figsize=(15,10),bins=30, edgecolor='black')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df['Attendance'].value_counts().plot(kind='bar')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df['Home Team Goals'].value_counts().plot(kind='line')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df['Away Team Goals'].value_counts().plot(kind='line')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.groupby('Attendance', as_index=False)['Home Team Goals'].mean().plot(kind='bar',x='Attendance',y=' Home Team Goals', title= 'Average Home Team Goals scored vs Attendance')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ' Home_Team_Goals'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 df.groupby('Attendance', as_index=False)['Home Team Goals'].mean().plot(kind='bar',x='Attendance',y=' Home_Team_Goals', title= 'Average Home Team Goals scored vs Attendance')
#       2 plt.show()
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/plotting/_core.py:1017, in PlotAccessor.__call__(self, *args, **kwargs)
#    1014             pass
#    1016 # don't overwrite
# -> 1017 data = data[y].copy()
#    1019 if isinstance(data, ABCSeries):
#    1020     label_name = label_kw or y
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: ' Home_Team_Goals'
